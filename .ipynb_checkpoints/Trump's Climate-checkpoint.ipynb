# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create a path to the csv and read it into a Pandas DataFrame
csv_path = "Resources/emissionpercapita.csv"

data = pd.read_csv(csv_path, index_col='Entity', encoding='utf8')

data
# Out:
#                 Year 2014 Emissions (tonnes per capita)  \
# Entity
# China                                          7.064447
# India                                          1.706162
# Japan                                          9.863802
# Russia                                        11.596374
# United Kingdom                                 6.747467
# United States                                 17.527322
#
#                 Year 2015 Emissions (tonnes per capita)  \
# Entity
# China                                          6.955096
# India                                          1.738971
# Japan                                          9.561765
# Russia                                        11.619420
# United Kingdom                                 6.463019
# United States                                 16.943764
#
#                 Year 2016 Emissions (tonnes per capita)  \
# Entity
# China                                          6.914483
# India                                          1.795423
# Japan                                          9.427261
# Russia                                        11.586674
# United Kingdom                                 6.058056
# United States                                 16.484164
#
#                 Year 2017 Emissions (tonnes per capita)
# Entity
# China                                          6.980229
# India                                          1.841997
# Japan                                          9.452613
# Russia                                        11.756356
# United Kingdom                                 5.812898
# United States                                 16.240949

# %%
# Extract year from last 4 characters of each column name
years = data.columns.str.strip('Year')
# Convert year values to integers, saving results back to dataframe

data.loc['China'].plot()

# %%
plt.style.use('ggplot')
data.T.plot(kind='bar')
plt.ylabel('CO₂ emissions per capita by Tonnes')
plt.legend(loc='best')
plt.xticks(rotation=60)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text xticklabel objects>)
