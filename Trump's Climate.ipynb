# %%
# Dependencies

# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create a path to the csv and read it into a Pandas DataFrame
csv_path = "Resources/emissionpercapita.csv"

data = pd.read_csv(csv_path, index_col='Entity', encoding='utf8')

data
# Out:
#                      2014       2015       2016       2017
# Entity
# China            7.064447   6.955096   6.914483   6.980229
# India            1.706162   1.738971   1.795423   1.841997
# Japan            9.863802   9.561765   9.427261   9.452613
# Russia          11.596374  11.619420  11.586674  11.756356
# United Kingdom   6.747467   6.463019   6.058056   5.812898
# United States   17.527322  16.943764  16.484164  16.240949

# %%
# Extract year from last 4 characters of each column name
years = data.columns.str.strip('Year')
# Convert year values to integers, saving results back to dataframe

# %%
plt.style.use('ggplot')
data.T.plot(kind='bar')
plt.title('Per capita CO2 Emissions')
plt.ylabel('CO₂ emissions per capita in Tonnes')
plt.legend(loc='best')
plt.xticks(rotation=60)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="936">

# %%
plt.savefig("Resources/trumpbar.png")
